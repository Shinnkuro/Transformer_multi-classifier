# %%
import pandas as pd
import awkward as ak
import os
import dask.dataframe as dd

# %%
import matplotlib.pyplot as plt

# %%
print(os.path.exists("/depot/cms/hu1027/hmm_ntuples/skimmed_for_dnn_AK8jets/merged/2018"))
# Out:
# True

# %%
path = [
    "/depot/cms/hu1027/hmm_ntuples/skimmed_for_dnn_AK8jets/merged/2018/dy_M-100To200_MiNNLO_merged.parquet",
    "/depot/cms/hu1027/hmm_ntuples/skimmed_for_dnn_AK8jets/merged/2018/dy_M-50_MiNNLO_merged.parquet",
]

path_af = "/depot/cms/hu1027/hmm_ntuples/skimmed_for_dnn_AK8jets/merged/2018/dy_VBF_filter_merged.parquet"

path_bf = "/depot/cms/hu1027/hmm_ntuples/skimmed_for_dnn_AK8jets/merged/2018/ggh_powhegPS_merged.parquet"

df_af = dd.read_parquet(path_af)
df_bf = dd.read_parquet(path_bf)
df = dd.read_parquet(path)

# %%
for c in df.columns:
    print(c)
# Out:
# MET_pt
# MET_phi
# mu1_pt
# mu2_pt
# mu1_pt_over_mass
# mu2_pt_over_mass
# mu1_eta
# mu2_eta
# mu1_phi
# mu2_phi
# dimuon_mass
# dimuon_pt
# dimuon_pt_log
# dimuon_rapidity
# dimuon_dR
# dimuon_ebe_mass_res
# dimuon_ebe_mass_res_rel
# dimuon_cos_theta_cs
# dimuon_phi_cs
# year
# nfatJets_drmuon
# gjj_mass
# jet1_pt_nominal
# jet1_eta_nominal
# jet1_phi_nominal
# jet1_qgl_nominal
# jet1_mass_nominal
# jet2_pt_nominal
# jet2_eta_nominal
# jet2_phi_nominal
# jet2_qgl_nominal
# jet2_mass_nominal
# jet3_pt_nominal
# jet3_eta_nominal
# jet3_phi_nominal
# jet3_qgl_nominal
# jet3_mass_nominal
# jet4_pt_nominal
# jet4_eta_nominal
# jet4_phi_nominal
# jet4_qgl_nominal
# jet4_mass_nominal
# jj_mass_nominal
# jj_mass_log_nominal
# jj_dEta_nominal
# jj_dPhi_nominal
# mmj_min_dEta_nominal
# mmj_min_dPhi_nominal
# rpt_nominal
# pt_centrality_nominal
# zeppenfeld_nominal
# ll_zstar_log_nominal
# njets_nominal
# htsoft2_nominal
# nsoftjets5_nominal
# nBtagLoose_nominal
# nBtagMedium_nominal
# ...

# %%
# path_af = [
#     "/depot/cms/hu1027/hmm_ntuples/skimmed_for_dnn_AK8jets/merged/2018/dy_M-100To200_MiNNLO_merged.parquet",
#     "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/dy_M-50_MiNNLO/0/part*.parquet",
#     "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/dy_M-100To200_MiNNLO/part*.parquet",
# ]
# path =[
#     "/depot/cms/hu1027/hmm_ntuples/skimmed_for_dnn_AK8jets/merged/2018/part*.parquet",
#     "/depot/cms/users/hu1027/hmm/copperheadV1clean/test1_original_sep2025/stage1_output/2018/f1_0/dy_M-50_MiNNLO/0/part*.parquet",
#     "/depot/cms/users/hu1027/hmm/copperheadV1clean/test1_original_sep2025/stage1_output/2018/f1_0/dy_M-100To200_MiNNLO/part*.parquet",
# ]

# %%
# path_af = "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/ggh_powhegPS/0/part*.parquet"
# path = "/depot/cms/users/hu1027/hmm/copperheadV1clean/test1_original_sep2025/stage1_output/2018/f1_0/ggh_powhegPS/0/part*.parquet"

# %%
# path_af = "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/ggH_category_in_h-peak/ggh_powhegPS/0/part*.parquet"
# path = [
#     # "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/dy_M-50/0/part*.parquet",
#     "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/ggH_category_in_h-peak/dy_M-50_MiNNLO/0/part*.parquet",
#     "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/ggH_category_in_h-peak/dy_M-100To200_MiNNLO/0/part*.parquet",
# ]

# %%
df_af = dd.read_parquet(path_af)
df_bf = dd.read_parquet(path_bf)
df = dd.read_parquet(path)

# wgt_af = df_af["wgt_nominal"].compute()
# wgt_bf = df_bf["wgt_nominal"].compute()
# wgt = df["wgt_nominal"].compute()

#muons
dimuon_pt_af = df_af["dimuon_pt"].compute()
dimuon_pt_bf = df_bf["dimuon_pt"].compute()
dimuon_pt = df["dimuon_pt"].compute()

dimuon_phi_cs_af = df_af["dimuon_phi_cs"].compute()
dimuon_phi_cs_bf = df_bf["dimuon_phi_cs"].compute()
dimuon_phi_cs = df["dimuon_phi_cs"].compute()

dimuon_cos_theta_eta_af = df_af["dimuon_cos_theta_cs"].compute()
dimuon_cos_theta_eta_bf = df_bf["dimuon_cos_theta_cs"].compute()
dimuon_cos_theta_eta = df["dimuon_cos_theta_cs"].compute()

mu1_pt_over_mass_af = df_af["mu1_pt_over_mass"].compute()
mu1_pt_over_mass_bf = df_bf["mu1_pt_over_mass"].compute()
mu1_pt_over_mass = df["mu1_pt_over_mass"].compute()

mu1_pt_af = df_af["mu1_pt"].compute()
mu1_pt_bf = df_bf["mu1_pt"].compute()
mu1_pt = df["mu1_pt"].compute()

mu2_pt_over_mass_af = df_af["mu2_pt_over_mass"].compute()
mu2_pt_over_mass_bf = df_bf["mu2_pt_over_mass"].compute()
mu2_pt_over_mass = df["mu2_pt_over_mass"].compute()

mu2_pt_af = df_af["mu2_pt"].compute()
mu2_pt_bf = df_bf["mu2_pt"].compute()
mu2_pt = df["mu2_pt"].compute()

mu1_eta_af = df_af["mu1_eta"].compute()
mu1_eta_bf = df_bf["mu1_eta"].compute()
mu1_eta = df["mu1_eta"].compute()

mu2_eta_af = df_af["mu2_eta"].compute()
mu2_eta_bf = df_bf["mu2_eta"].compute()
mu2_eta = df["mu2_eta"].compute()

# jets
jet1_pt_nominal_af = df_af["jet1_pt_nominal"].compute()
jet1_pt_nominal_bf = df_bf["jet1_pt_nominal"].compute()
jet1_pt_nominal = df["jet1_pt_nominal"].compute()

jet1_eta_nominal_af = df_af["jet1_eta_nominal"].compute()
jet1_eta_nominal_bf = df_bf["jet1_eta_nominal"].compute()
jet1_eta_nominal = df["jet1_eta_nominal"].compute()

jet2_pt_nominal_af = df_af["jet2_pt_nominal"].compute()
jet2_pt_nominal_bf = df_bf["jet2_pt_nominal"].compute()
jet2_pt_nominal = df["jet2_pt_nominal"].compute()

njets_nominal_af = df_af["njets_nominal"].compute()
njets_nominal_bf = df_bf["njets_nominal"].compute()
njets_nominal = df["njets_nominal"].compute()

jj_mass_nominal_af = df_af["jj_mass_nominal"].compute()
jj_mass_nominal_bf = df_bf["jj_mass_nominal"].compute()
jj_mass_nominal = df["jj_mass_nominal"].compute()

jj_dEta_nominal_af = df_af["jj_dEta_nominal"].compute()
jj_dEta_nominal_bf = df_bf["jj_dEta_nominal"].compute()
jj_dEta_nominal = df["jj_dEta_nominal"].compute()

jj_dPhi_nominal_af = df_af["jj_dPhi_nominal"].compute()
jj_dPhi_nominal_bf = df_bf["jj_dPhi_nominal"].compute()
jj_dPhi_nominal = df["jj_dPhi_nominal"].compute()

zeppenfeld_nominal_af = df_af["zeppenfeld_nominal"].compute()
zeppenfeld_nominal_bf = df_bf["zeppenfeld_nominal"].compute()
zeppenfeld_nominal = df["zeppenfeld_nominal"].compute()

mmj_min_dPhi_nominal_af = df_af["mmj_min_dPhi_nominal"].compute()
mmj_min_dPhi_nominal_bf = df_bf["mmj_min_dPhi_nominal"].compute()
mmj_min_dPhi_nominal = df["mmj_min_dPhi_nominal"].compute()

mmj_min_dEta_nominal_af = df_af["mmj_min_dEta_nominal"].compute()
mmj_min_dEta_nominal_bf = df_bf["mmj_min_dEta_nominal"].compute()
mmj_min_dEta_nominal = df["mmj_min_dEta_nominal"].compute()

# %%
print(mu1_pt_af)
# Out:
# 0        50.439612
# 1        85.782077
# 2        61.755254
# 3        46.425089
# 4        56.666740
#            ...
# 20066    69.469921
# 20067    63.692082
# 20068    56.731783
# 20069    65.217304
# 20070    71.743493
# Name: mu1_pt, Length: 540253, dtype: float64

# %%
print(mu1_pt_over_mass_af)
# Out:
# 0        0.400421
# 1        0.684936
# 2        0.491505
# 3        0.376680
# 4        0.446479
#            ...
# 20066    0.559480
# 20067    0.517759
# 20068    0.477479
# 20069    0.529860
# 20070    0.588923
# Name: mu1_pt_over_mass, Length: 540253, dtype: float64

# %%
df_af = dd.read_parquet(path_af)
df = dd.read_parquet(path)

wgt_af = df_af["wgt_nominal"].compute()
wgt = df["wgt_nominal"].compute()

dimuon_ebe_mass_res_rel_af = df_af["dimuon_ebe_mass_res_rel"].compute()
dimuon_ebe_mass_res_rel = df["dimuon_ebe_mass_res_rel"].compute()

dimuon_ebe_mass_res_af = df_af["dimuon_ebe_mass_res"].compute()
dimuon_ebe_mass_res = df["dimuon_ebe_mass_res"].compute()

# %%
mask = (jet1_pt_nominal > 60) & (jet2_pt_nominal > 40)
mask_af = (jet1_pt_nominal_af > 60) & (jet2_pt_nominal_af > 40)
mask_bf = (jet1_pt_nominal_bf > 60) & (jet2_pt_nominal_bf > 40)

# %%
plt.hist(dimuon_ebe_mass_res_rel_af[mask_af], bins=50, range=(0,0.04), density=True, histtype="step", color="blue", label="VBF")
plt.hist(dimuon_ebe_mass_res_rel_bf[mask_bf], bins=50, range=(0,0.04), density=True, histtype="step", color="green", label="ggH")
plt.hist(dimuon_ebe_mass_res_rel[mask], bins=50,  range=(0,0.04), density=True, histtype="step", color="red", label="DY")
#plt.hist(dimuon_pt, bins=50,  range=(0,200), histtype="step", color="red",label="DY")
plt.xlabel(r"${\sigma_{\mu\mu}/{m_{\mu\mu}}}$ [GeV]")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
dimuon_ebe_mass_res_af = df_af["dimuon_ebe_mass_res"].compute()
dimuon_ebe_mass_res = df["dimuon_ebe_mass_res"].compute()
dimuon_ebe_mass_res_bf = df_bf["dimuon_ebe_mass_res"].compute()

plt.hist(dimuon_ebe_mass_res_af[mask_af], bins=50, range=(0,5), density=True, histtype="step", color="blue", label="VBF")
plt.hist(dimuon_ebe_mass_res_bf[mask_bf], bins=50, range=(0,5), density=True, histtype="step", color="green", label="ggH")
plt.hist(dimuon_ebe_mass_res[mask], bins=50,  range=(0,5), density=True, histtype="step", color="red", label="DY")
#plt.hist(dimuon_pt, bins=50,  range=(0,200), histtype="step", color="red",label="DY")
plt.xlabel(r"$\sigma_{\mu\mu}$ [GeV]")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
dimuon_pt_af = df_af["dimuon_pt"].compute()
dimuon_pt_bf = df_bf["dimuon_pt"].compute()
dimuon_pt = df["dimuon_pt"].compute()

plt.hist(dimuon_pt_af[mask_af], bins=50, range=(0,200), density=True, histtype="step", color="blue", label="VBF")
plt.hist(dimuon_pt_bf[mask_bf], bins=50, range=(0,200), density=True, histtype="step", color="green", label="ggH")
plt.hist(dimuon_pt[mask], bins=50, range=(0,200), density=True, histtype="step", color="red", label="DY")

#plt.hist(dimuon_pt, bins=50,  range=(0,200), histtype="step", color="red",label="DY")
plt.xlabel(r"$p_T^{\mu\mu}$ [GeV]")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
dimuon_rapidity_af = df_af["dimuon_rapidity"].compute()
dimuon_rapidity_bf = df_bf["dimuon_rapidity"].compute()
dimuon_rapidity = df["dimuon_rapidity"].compute()

plt.hist(dimuon_rapidity_af[mask_af], bins=50, density=True, range=(-2.5,2.5), histtype="step", color="blue", label="VBF")
plt.hist(dimuon_rapidity_bf[mask_bf], bins=50, density=True, range=(-2.5,2.5), histtype="step", color="green", label="ggH")
plt.hist(dimuon_rapidity[mask], bins=50, density=True,  range=(-2.5,2.5), histtype="step", color="red",label="DY")
plt.xlabel(r"$y_{\mu\mu}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
dimuon_phi_cs_af = df_af["dimuon_phi_cs"].compute()
dimuon_phi_cs_bf = df_bf["dimuon_phi_cs"].compute()
dimuon_phi_cs = df["dimuon_phi_cs"].compute()

plt.hist(dimuon_phi_cs_af[mask_af], bins=50, density=True,  range=(-3,3), histtype="step", color="blue", label="VBF")
plt.hist(dimuon_phi_cs_bf[mask_bf], bins=50, density=True,  range=(-3,3), histtype="step", color="green", label="ggH")
plt.hist(dimuon_phi_cs[mask], bins=50, density=True, range=(-3,3), histtype="step", color="red",label="DY")
plt.xlabel(r"$\phi_{\text{CS}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
dimuon_cos_theta_eta_af = df_af["dimuon_cos_theta_cs"].compute()
dimuon_cos_theta_eta_bf = df_bf["dimuon_cos_theta_cs"].compute()
dimuon_cos_theta_eta = df["dimuon_cos_theta_cs"].compute()

plt.hist(dimuon_cos_theta_eta_af[mask_af], bins=50, density=True, range=(-1,1), histtype="step", color="blue", label="VBF")
plt.hist(dimuon_cos_theta_eta_bf[mask_bf], bins=50, density=True, range=(-1,1), histtype="step", color="green", label="ggH")
plt.hist(dimuon_cos_theta_eta[mask], bins=50, density=True,  range=(-1,1), histtype="step", color="red",label="DY")
plt.xlabel(r"$\cos\theta_{\text{CS}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
mu1_pt_over_mass_af = df_af["mu1_pt_over_mass"].compute()
mu1_pt_over_mass_bf = df_bf["mu1_pt_over_mass"].compute()
mu1_pt_over_mass = df["mu1_pt_over_mass"].compute()

plt.hist(mu1_pt_over_mass_af[mask_af], bins=50, density=True, range=(0,1.4), histtype="step", color="blue", label="VBF")
plt.hist(mu1_pt_over_mass_bf[mask_bf], bins=50, density=True, range=(0,1.4), histtype="step", color="green", label="ggH")
plt.hist(mu1_pt_over_mass[mask], bins=50,  density=True, range=(0,1.4), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{\mu_1}}/{m_{\mu\mu}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
mu1_pt_af = df_af["mu1_pt"].compute()
mu1_pt_bf = df_bf["mu1_pt"].compute()
mu1_pt = df["mu1_pt"].compute()

plt.hist(mu1_pt_af[mask_af], bins=50, density=True, range=(0,200), histtype="step", color="blue", label="VBF")
plt.hist(mu1_pt_bf[mask_bf], bins=50, density=True, range=(0,200), histtype="step", color="green", label="ggH")
plt.hist(mu1_pt[mask], bins=50,  density=True, range=(0,200), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{\mu_1}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
mu2_pt_over_mass_af = df_af["mu2_pt_over_mass"].compute()
mu2_pt_over_mass_bf = df_bf["mu2_pt_over_mass"].compute()
mu2_pt_over_mass = df["mu2_pt_over_mass"].compute()

plt.hist(mu2_pt_over_mass_af[mask_af], bins=50, density=True, range=(0,0.8), histtype="step", color="blue", label="VBF")
plt.hist(mu2_pt_over_mass_bf[mask_bf], bins=50, density=True, range=(0,0.8), histtype="step", color="green", label="ggH")
plt.hist(mu2_pt_over_mass[mask], bins=50,  density=True, range=(0,0.8), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{\mu_2}}/{m_{\mu\mu}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
mu2_pt_af = df_af["mu2_pt"].compute()
mu2_pt_bf = df_bf["mu2_pt"].compute()
mu2_pt = df["mu2_pt"].compute()

plt.hist(mu2_pt_af[mask_af], bins=50, density=True, range=(10,100), histtype="step", color="blue", label="VBF")
plt.hist(mu2_pt_bf[mask_bf], bins=50, density=True, range=(10,100), histtype="step", color="green", label="ggH")
plt.hist(mu2_pt[mask], bins=50,  density=True, range=(10,100), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{\mu_2}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
mu1_eta_af = df_af["mu1_eta"].compute()
mu1_eta_bf = df_bf["mu1_eta"].compute()
mu1_eta = df["mu1_eta"].compute()

plt.hist(mu1_eta_af[mask_af], bins=50, density=True, range=(-2.5,2.5), histtype="step", color="blue", label="VBF")
plt.hist(mu1_eta_bf[mask_bf], bins=50, density=True, range=(-2.5,2.5), histtype="step", color="green", label="ggH")
plt.hist(mu1_eta[mask], bins=50,  density=True, range=(-2.5,2.5), histtype="step", color="red",label="DY")
plt.xlabel(r"$\eta_{\mu_1}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
mu2_eta_af = df_af["mu2_eta"].compute()
mu2_eta_bf = df_bf["mu2_eta"].compute()
mu2_eta = df["mu2_eta"].compute()

plt.hist(mu2_eta_af[mask_af], bins=50,density=True,  range=(-2.5,2.5), histtype="step", color="blue", label="VBF")
plt.hist(mu2_eta_bf[mask_bf], bins=50,density=True,  range=(-2.5,2.5), histtype="step", color="green", label="ggH")
plt.hist(mu2_eta[mask], bins=50,  density=True, range=(-2.5,2.5), histtype="step", color="red",label="DY")
plt.xlabel(r"$\eta_{\mu_2}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
jet1_pt_nominal_af = df_af["jet1_pt_nominal"].compute()
jet1_pt_nominal_bf = df_bf["jet1_pt_nominal"].compute()
jet1_pt_nominal = df["jet1_pt_nominal"].compute()

plt.hist(jet1_pt_nominal_af[mask_af], bins=50, density=True, range=(0,300), histtype="step", color="blue", label="VBF")
plt.hist(jet1_pt_nominal_bf[mask_bf], bins=50, density=True, range=(0,300), histtype="step", color="green", label="ggH")
plt.hist(jet1_pt_nominal[mask], bins=50, density=True,  range=(0,300), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{j_1}}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log")  
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
jet1_eta_nominal_af = df_af["jet1_eta_nominal"].compute()
jet1_eta_nominal_bf = df_bf["jet1_eta_nominal"].compute()
jet1_eta_nominal = df["jet1_eta_nominal"].compute()

plt.hist(jet1_eta_nominal_af[mask_af], bins=50, density=True, range=(-5,5), histtype="step", color="blue", label="VBF")
plt.hist(jet1_eta_nominal_bf[mask_bf], bins=50, density=True, range=(-5,5), histtype="step", color="green", label="ggH")
plt.hist(jet1_eta_nominal[mask], bins=50, density=True,  range=(-5,5), histtype="step", color="red",label="DY")
plt.xlabel(r"$\eta_{j_1}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
print()

# %%
jet2_pt_nominal_af = df_af["jet2_pt_nominal"].compute()
jet2_pt_nominal_bf = df_bf["jet2_pt_nominal"].compute()
jet2_pt_nominal = df["jet2_pt_nominal"].compute()

plt.hist(jet2_pt_nominal_af[mask_af], bins=50, density=True, range=(0,300), histtype="step", color="blue", label="VBF")
plt.hist(jet2_pt_nominal_bf[mask_bf], bins=50, density=True, range=(0,300), histtype="step", color="green", label="ggH")
plt.hist(jet2_pt_nominal[mask], bins=50, density=True,  range=(0,300), histtype="step", color="red",label="DY")
plt.xlabel(r"$p_T^{j_2}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
njets_nominal_af = df_af["njets_nominal"].compute()
njets_nominal_bf = df_bf["njets_nominal"].compute()
njets_nominal = df["njets_nominal"].compute()

plt.hist(njets_nominal_af[mask_af], bins=7, density=True, range=(0,7), histtype="step", color="blue", label="VBF")
plt.hist(njets_nominal_bf[mask_bf], bins=7, density=True, range=(0,7), histtype="step", color="green", label="ggH")
plt.hist(njets_nominal[mask], bins=7, density=True,  range=(0,7), histtype="step", color="red",label="DY")
plt.xlabel(r"$N_{\text{jets}}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
jj_mass_nominal_af = df_af["jj_mass_nominal"].compute()
jj_mass_nominal_bf = df_bf["jj_mass_nominal"].compute()
jj_mass_nominal = df["jj_mass_nominal"].compute()

plt.hist(jj_mass_nominal_af[mask_af], bins=50, density=True, range=(0,700), histtype="step", color="blue", label="VBF")
plt.hist(jj_mass_nominal_bf[mask_bf], bins=50, density=True, range=(0,700), histtype="step", color="green", label="ggH")
plt.hist(jj_mass_nominal[mask], bins=50, density=True,  range=(0,700), histtype="step", color="red",label="DY")
plt.xlabel(r"$m_{jj}$")
plt.ylabel("a.u.")
plt.legend()
#plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
jj_dEta_nominal_af = df_af["jj_dEta_nominal"].compute()
jj_dEta_nominal_bf = df_bf["jj_dEta_nominal"].compute()
jj_dEta_nominal = df["jj_dEta_nominal"].compute()

plt.hist(jj_dEta_nominal_af[mask_af], bins=50, density=True, range=(0,8), histtype="step", color="blue", label="VBF")
plt.hist(jj_dEta_nominal_bf[mask_bf], bins=50, density=True, range=(0,8), histtype="step", color="green", label="ggH")
plt.hist(jj_dEta_nominal[mask], bins=50, density=True,  range=(0,8), histtype="step", color="red",label="DY")
plt.xlabel(r"$\Delta \eta_{jj}$")
plt.ylabel("a.u.")
plt.legend()
#plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
jj_dPhi_nominal_af = df_af["jj_dPhi_nominal"].compute()
jj_dPhi_nominal_bf = df_bf["jj_dPhi_nominal"].compute()
jj_dPhi_nominal = df["jj_dPhi_nominal"].compute()

plt.hist(jj_dPhi_nominal_af[mask_af], bins=50, density=True, range=(0,3), histtype="step", color="blue", label="VBF")
plt.hist(jj_dPhi_nominal_bf[mask_bf], bins=50, density=True, range=(0,3), histtype="step", color="green", label="ggH")
plt.hist(jj_dPhi_nominal[mask], bins=50, density=True,  range=(0,3), histtype="step", color="red",label="DY")
plt.xlabel(r"$\Delta \phi_{jj}$")
plt.ylabel("a.u.")
plt.legend()
#plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
print(jj_dPhi_nominal)
# Out:
# 0        -9.0
# 1        -9.0
# 2        -9.0
# 3        -9.0
# 4        -9.0
#          ...
# 314626   -9.0
# 314627   -9.0
# 314628   -9.0
# 314629   -9.0
# 314630   -9.0
# Name: jj_dPhi_nominal, Length: 318142, dtype: float64

# %%
zeppenfeld_nominal_af = df_af["zeppenfeld_nominal"].compute()
zeppenfeld_nominal_bf = df_bf["zeppenfeld_nominal"].compute()
zeppenfeld_nominal = df["zeppenfeld_nominal"].compute()

plt.hist(zeppenfeld_nominal_af[mask_af], bins=50, density=True, range=(-6,6), histtype="step", color="blue", label="VBF")
plt.hist(zeppenfeld_nominal_bf[mask_bf], bins=50, density=True, range=(-6,6), histtype="step", color="green", label="ggH")
plt.hist(zeppenfeld_nominal[mask], bins=50, density=True,  range=(-6,6), histtype="step", color="red",label="DY")
plt.xlabel(r"$z^*(H)$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
mmj_min_dPhi_nominal_af = df_af["mmj_min_dPhi_nominal"].compute()
mmj_min_dPhi_nominal_bf = df_bf["mmj_min_dPhi_nominal"].compute()
mmj_min_dPhi_nominal = df["mmj_min_dPhi_nominal"].compute()

plt.hist(mmj_min_dPhi_nominal_af[mask_af], bins=50,density=True,  range=(0,3), histtype="step", color="blue", label="VBF")
plt.hist(mmj_min_dPhi_nominal_bf[mask_bf], bins=50,density=True,  range=(0,3), histtype="step", color="green", label="ggH")
plt.hist(mmj_min_dPhi_nominal[mask], bins=50, density=True,  range=(0,3), histtype="step", color="red",label="DY")
plt.xlabel(r"$\min\{\Delta \eta(\mu\mu, j_1), \Delta \eta(\mu\mu, j_2)\}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
mmj_min_dEta_nominal_af = df_af["mmj_min_dEta_nominal"].compute()
mmj_min_dEta_nominal_bf = df_bf["mmj_min_dEta_nominal"].compute()
mmj_min_dEta_nominal = df["mmj_min_dEta_nominal"].compute()

plt.hist(mmj_min_dEta_nominal_af[mask_af], bins=50, density=True, range=(0,8), histtype="step", color="blue", label="VBF")
plt.hist(mmj_min_dEta_nominal_bf[mask_bf], bins=50, density=True, range=(0,8), histtype="step", color="green", label="ggH")
plt.hist(mmj_min_dEta_nominal[mask], bins=50, density=True,  range=(0,8), histtype="step", color="red",label="DY")
plt.xlabel(r"$\min\{\Delta \phi(\mu\mu, j_1), \Delta \phi(\mu\mu, j_2)\}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
for c in df.columns:
    print(c)
# Out:
# event
# PV_npvs
# PV_npvsGood
# MET_pt
# MET_phi
# MET_sumEt
# mu1_pt
# mu1_ptErr
# mu2_pt
# mu2_ptErr
# mu1_pt_over_mass
# mu2_pt_over_mass
# mu1_eta
# mu2_eta
# mu1_phi
# mu2_phi
# mu1_charge
# mu2_charge
# mu1_iso
# mu2_iso
# nmuons
# dimuon_mass
# dimuon_pt
# dimuon_pt_log
# dimuon_eta
# dimuon_rapidity
# dimuon_phi
# dimuon_dEta
# dimuon_dPhi
# dimuon_dR
# acoplanarity
# dimuon_ebe_mass_res
# dimuon_ebe_mass_res_rel
# uncalibrated_dimuon_ebe_mass_res
# dimuon_cos_theta_cs
# dimuon_phi_cs
# dimuon_cos_theta_eta
# dimuon_phi_eta
# mu1_pt_raw
# mu2_pt_raw
# mu1_pt_fsr
# mu2_pt_fsr
# year
# run
# luminosityBlock
# fraction
# jet1_default_pt_nominal
# jet1_default_eta_nominal
# jet2_default_pt_nominal
# jet2_default_eta_nominal
# gjet1_pt
# gjet1_eta
# gjet1_phi
# gjet1_mass
# gjet2_pt
# gjet2_eta
# gjet2_phi
# gjet2_mass
# gjj_pt
# gjj_eta
# gjj_phi
# gjj_mass
# gjj_dEta
# gjj_dPhi
# gjj_dR
# jet1_pt_nominal
# jet1_eta_nominal
# jet1_rapidity_nominal
# jet1_phi_nominal
# ...

# %%
dfD.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 dfD.columns
#
# NameError: name 'dfD' is not defined

# %%
dfD.loc[:50,:].compute()

# %%
! ls /depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/

# %%
print(df.head())

# %%
# df.columns.tolist()
for col in df.columns:
    if "even" in col:
        print(col)

# %%
df["event"]

# %%
print(df.columns)

# %%
print(df["mu1_pt"][:10])

# %%
import matplotlib.pyplot as plt

# %%
# !ls /eos/purdue/store/user/rasharma/customNanoAOD/UL2018/GluGluHToMuMu_M125_TuneCP5_13TeV-powheg-pythia8

# %%
plt.hist(df["mu1_pt"], bins=50, range=(0,200), histtype="step", color="blue", label="VBF", label=r"$\mu_1 \, p_T$")
plt.hist(df["mu2_pt"], bins=50, range=(0,200), histtype="step", color="red",label="DY", label=r"$\mu_2 \, p_T$")

plt.xlabel(r"Muon $p_T$ [GeV]")
plt.ylabel("a.u.")plt.legend()
plt.title(r"Distribution of leading ($\mu_1$) and subleading ($\mu_2$) muon $p_T$")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()
