# %%
import pandas as pd
import awkward as ak
import os
import dask.dataframe as dd

# %%
import matplotlib.pyplot as plt

# %%
print(os.path.exists("/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/ggH_category_in_h-peak/dy_M-100To200_MiNNLO/0/part000.parquet"))
# Out:
# True

# %%
path_af = [
    "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/dy_M-50/0/part*.parquet",
    "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/dy_M-50_MiNNLO/0/part*.parquet",
    "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/dy_M-100To200_MiNNLO/part*.parquet",
]
path =[
    "/depot/cms/users/hu1027/hmm/copperheadV1clean/test1_original_sep2025/stage1_output/2018/f1_0/dy_M-50/0/part*.parquet",
    "/depot/cms/users/hu1027/hmm/copperheadV1clean/test1_original_sep2025/stage1_output/2018/f1_0/dy_M-50_MiNNLO/0/part*.parquet",
    "/depot/cms/users/hu1027/hmm/copperheadV1clean/test1_original_sep2025/stage1_output/2018/f1_0/dy_M-100To200_MiNNLO/part*.parquet",
]

# %%
path_af = "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/ggh_powhegPS/0/part*.parquet"
path = "/depot/cms/users/hu1027/hmm/copperheadV1clean/test1_original_sep2025/stage1_output/2018/f1_0/ggh_powhegPS/0/part*.parquet"

# %%
path_af = "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/ggH_category_in_h-peak/ggh_powhegPS/0/part*.parquet"
path = [
    # "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/dy_M-50/0/part*.parquet",
    "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/ggH_category_in_h-peak/dy_M-50_MiNNLO/0/part*.parquet",
    "/depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/ggH_category_in_h-peak/dy_M-100To200_MiNNLO/0/part*.parquet",
]

# %%
df_af = dd.read_parquet(path_af)
df = dd.read_parquet(path)

wgt_af = df_af["wgt_nominal"].compute()
wgt = df["wgt_nominal"].compute()

#muons
dimuon_pt_af = df_af["dimuon_pt"].compute()
dimuon_pt = df["dimuon_pt"].compute()

dimuon_rapidity_af = df_af["dimuon_rapidity"].compute()
dimuon_rapidity = df["dimuon_rapidity"].compute()

dimuon_phi_cs_af = df_af["dimuon_phi_cs"].compute()
dimuon_phi_cs = df["dimuon_phi_cs"].compute()

dimuon_cos_theta_eta_af = df_af["dimuon_cos_theta_eta"].compute()
dimuon_cos_theta_eta = df["dimuon_cos_theta_eta"].compute()

mu1_pt_over_mass_af = df_af["mu1_pt_over_mass"].compute()
mu1_pt_over_mass = df["mu1_pt_over_mass"].compute()

mu1_pt_af = df_af["mu1_pt"].compute()
mu1_pt = df["mu1_pt"].compute()

mu2_pt_over_mass_af = df_af["mu2_pt_over_mass"].compute()
mu2_pt_over_mass = df["mu2_pt_over_mass"].compute()

mu2_pt_af = df_af["mu2_pt"].compute()
mu2_pt = df["mu2_pt"].compute()

mu1_eta_af = df_af["mu1_eta"].compute()
mu1_eta = df["mu1_eta"].compute()

mu2_eta_af = df_af["mu2_eta"].compute()
mu2_eta = df["mu2_eta"].compute()

# jets
jet1_pt_nominal_af = df_af["jet1_pt_nominal"].compute()
jet1_pt_nominal = df["jet1_pt_nominal"].compute()

jet1_eta_nominal_af = df_af["jet1_eta_nominal"].compute()
jet1_eta_nominal = df["jet1_eta_nominal"].compute()

jet2_pt_nominal_af = df_af["jet2_pt_nominal"].compute()
jet2_pt_nominal = df["jet2_pt_nominal"].compute()

njets_nominal_af = df_af["njets_nominal"].compute()
njets_nominal = df["njets_nominal"].compute()

jj_mass_nominal_af = df_af["jj_mass_nominal"].compute()
jj_mass_nominal = df["jj_mass_nominal"].compute()

jj_dEta_nominal_af = df_af["jj_dEta_nominal"].compute()
jj_dEta_nominal = df["jj_dEta_nominal"].compute()

jj_dPhi_nominal_af = df_af["jj_dPhi_nominal"].compute()
jj_dPhi_nominal = df["jj_dPhi_nominal"].compute()

zeppenfeld_nominal_af = df_af["zeppenfeld_nominal"].compute()
zeppenfeld_nominal = df["zeppenfeld_nominal"].compute()

mmj_min_dPhi_nominal_af = df_af["mmj_min_dPhi_nominal"].compute()
mmj_min_dPhi_nominal = df["mmj_min_dPhi_nominal"].compute()

mmj_min_dEta_nominal_af = df_af["mmj_min_dEta_nominal"].compute()
mmj_min_dEta_nominal = df["mmj_min_dEta_nominal"].compute()

# df = df.loc[:50,:].compute()
# mu1_pt = df["mu1_pt"].compute()

# %%
print(mu1_pt_af)
# Out:
# 0        50.439612
# 1        85.782077
# 2        61.755254
# 3        46.425089
# 4        56.666740
#            ...
# 20066    69.469921
# 20067    63.692082
# 20068    56.731783
# 20069    65.217304
# 20070    71.743493
# Name: mu1_pt, Length: 540253, dtype: float64

# %%
print(mu1_pt_over_mass_af)
# Out:
# 0        0.400421
# 1        0.684936
# 2        0.491505
# 3        0.376680
# 4        0.446479
#            ...
# 20066    0.559480
# 20067    0.517759
# 20068    0.477479
# 20069    0.529860
# 20070    0.588923
# Name: mu1_pt_over_mass, Length: 540253, dtype: float64

# %%
df_af = dd.read_parquet(path_af)
df = dd.read_parquet(path)

wgt_af = df_af["wgt_nominal"].compute()
wgt = df["wgt_nominal"].compute()

dimuon_ebe_mass_res_rel_af = df_af["dimuon_ebe_mass_res_rel"].compute()
dimuon_ebe_mass_res_rel = df["dimuon_ebe_mass_res_rel"].compute()

dimuon_ebe_mass_res_af = df_af["dimuon_ebe_mass_res"].compute()
dimuon_ebe_mass_res = df["dimuon_ebe_mass_res"].compute()

# %%
plt.hist(dimuon_ebe_mass_res_rel_af, bins=50, weights=wgt_af, range=(0,0.04), density=True, histtype="step", color="blue", label="Signal")
plt.hist(dimuon_ebe_mass_res_rel, bins=50, weights=wgt, range=(0,0.04), density=True, histtype="step", color="red", label="DY")
#plt.hist(dimuon_pt, bins=50, weights=wgt, range=(0,200), histtype="step", color="red",label="DY")
plt.xlabel(r"${\sigma_{\mu\mu}/{m_{\mu\mu}}}$ [GeV]")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(dimuon_ebe_mass_res_af, bins=50, weights=wgt_af, range=(0,5), density=True, histtype="step", color="blue", label="Signal")
plt.hist(dimuon_ebe_mass_res, bins=50, weights=wgt, range=(0,5), density=True, histtype="step", color="red", label="DY")
#plt.hist(dimuon_pt, bins=50, weights=wgt, range=(0,200), histtype="step", color="red",label="DY")
plt.xlabel(r"$\sigma_{\mu\mu}$ [GeV]")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(dimuon_pt_af, bins=50, weights=wgt_af, range=(0,200), density=True, histtype="step", color="blue", label="Signal")
plt.hist(dimuon_pt, bins=50, weights=wgt, range=(0,200), density=True, histtype="step", color="red", label="DY")
#plt.hist(dimuon_pt, bins=50, weights=wgt, range=(0,200), histtype="step", color="red",label="DY")
plt.xlabel(r"$p_T^{\mu\mu}$ [GeV]")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(dimuon_rapidity_af, bins=50, density=True, weights=wgt_af, range=(-2.5,2.5), histtype="step", color="blue", label="Signal")
plt.hist(dimuon_rapidity, bins=50, density=True, weights=wgt, range=(-2.5,2.5), histtype="step", color="red",label="DY")
plt.xlabel(r"$y_{\mu\mu}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(dimuon_phi_cs_af, bins=50, density=True,weights=wgt_af, range=(-3,3), histtype="step", color="blue", label="Signal")
plt.hist(dimuon_phi_cs, bins=50, density=True,weights=wgt, range=(-3,3), histtype="step", color="red",label="DY")
plt.xlabel(r"$\phi_{\text{CS}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(dimuon_cos_theta_eta_af, bins=50, density=True, weights=wgt_af, range=(-1,1), histtype="step", color="blue", label="Signal")
plt.hist(dimuon_cos_theta_eta, bins=50, density=True, weights=wgt, range=(-1,1), histtype="step", color="red",label="DY")
plt.xlabel(r"$\cos\theta_{\text{CS}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(mu1_pt_over_mass_af, bins=50, weights=wgt_af, density=True, range=(0,1.4), histtype="step", color="blue", label="Signal")
plt.hist(mu1_pt_over_mass, bins=50, weights=wgt, density=True, range=(0,1.4), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{\mu_1}}/{m_{\mu\mu}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(mu1_pt_af, bins=50, weights=wgt_af, density=True, range=(0,200), histtype="step", color="blue", label="Signal")
plt.hist(mu1_pt, bins=50, weights=wgt, density=True, range=(0,200), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{\mu_1}}/{m_{\mu\mu}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(mu2_pt_over_mass_af, bins=50, weights=wgt_af, density=True, range=(0,0.8), histtype="step", color="blue", label="Signal")
plt.hist(mu2_pt_over_mass, bins=50, weights=wgt, density=True, range=(0,0.8), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{\mu_2}}/{m_{\mu\mu}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(mu2_pt_af, bins=50, weights=wgt_af, density=True, range=(10,100), histtype="step", color="blue", label="Signal")
plt.hist(mu2_pt, bins=50, weights=wgt, density=True, range=(10,100), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{\mu_1}}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(mu1_eta_af, bins=50, weights=wgt_af, density=True, range=(-2.5,2.5), histtype="step", color="blue", label="Signal")
plt.hist(mu1_eta, bins=50, weights=wgt, density=True, range=(-2.5,2.5), histtype="step", color="red",label="DY")
plt.xlabel(r"$\eta_{\mu_1}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(mu2_eta_af, bins=50, weights=wgt_af,density=True,  range=(-2.5,2.5), histtype="step", color="blue", label="Signal")
plt.hist(mu2_eta, bins=50, weights=wgt, density=True, range=(-2.5,2.5), histtype="step", color="red",label="DY")
plt.xlabel(r"$\eta_{\mu_2}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(jet1_pt_nominal_af, bins=50, density=True, weights=wgt_af, range=(0,500), histtype="step", color="blue", label="Signal")
plt.hist(jet1_pt_nominal, bins=50, density=True, weights=wgt, range=(0,500), histtype="step", color="red",label="DY")
plt.xlabel(r"${p_T^{j_1}}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log")  
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(jet1_eta_nominal_af, bins=50, density=True, weights=wgt_af, range=(-5,5), histtype="step", color="blue", label="Signal")
plt.hist(jet1_eta_nominal, bins=50, density=True, weights=wgt, range=(-5,5), histtype="step", color="red",label="DY")
plt.xlabel(r"$\eta_{j_1}$")
plt.ylabel("a.u.")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
print()

# %%
plt.hist(jet2_pt_nominal_af, bins=50, density=True, weights=wgt_af, range=(0,300), histtype="step", color="blue", label="Signal")
plt.hist(jet2_pt_nominal, bins=50, density=True, weights=wgt, range=(0,300), histtype="step", color="red",label="DY")
plt.xlabel(r"$p_T^{j_2}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(njets_nominal_af, bins=7, density=True, weights=wgt_af, range=(0,7), histtype="step", color="blue", label="Signal")
plt.hist(njets_nominal, bins=7, density=True, weights=wgt, range=(0,7), histtype="step", color="red",label="DY")
plt.xlabel(r"$N_{\text{jets}}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(jj_mass_nominal_af, bins=50, density=True, weights=wgt_af, range=(0,700), histtype="step", color="blue", label="Signal")
plt.hist(jj_mass_nominal, bins=50, density=True, weights=wgt, range=(0,700), histtype="step", color="red",label="DY")
plt.xlabel(r"$m_{jj}$")
plt.ylabel("a.u.")
plt.legend()
#plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(jj_dEta_nominal_af, bins=50, density=True, weights=wgt_af, range=(0,8), histtype="step", color="blue", label="Signal")
plt.hist(jj_dEta_nominal, bins=50, density=True, weights=wgt, range=(0,8), histtype="step", color="red",label="DY")
plt.xlabel(r"$\Delta \eta_{jj}$")
plt.ylabel("a.u.")
plt.legend()
#plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(jj_dPhi_nominal_af, bins=50, density=True, weights=wgt_af, range=(0,3), histtype="step", color="blue", label="Signal")
plt.hist(jj_dPhi_nominal, bins=50, density=True, weights=wgt, range=(0,3), histtype="step", color="red",label="DY")
plt.xlabel(r"$\Delta \phi_{jj}$")
plt.ylabel("a.u.")
plt.legend()
#plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
print(jj_dPhi_nominal)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 0      NaN
# 1      NaN
#         ..
# 2966   NaN
# 2967   NaN
# 2968   NaN
# 2969   NaN
# 2970   NaN
# Name: jj_dPhi_nominal, Length: 322315, dtype: float32

# %%
plt.hist(zeppenfeld_nominal_af, bins=50, density=True, weights=wgt_af, range=(-6,6), histtype="step", color="blue", label="Signal")
plt.hist(zeppenfeld_nominal, bins=50, density=True, weights=wgt, range=(-6,6), histtype="step", color="red",label="DY")
plt.xlabel(r"$z^*(H)$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(mmj_min_dPhi_nominal_af, bins=50,density=True,  weights=wgt_af, range=(0,3), histtype="step", color="blue", label="Signal")
plt.hist(mmj_min_dPhi_nominal, bins=50, density=True, weights=wgt, range=(0,3), histtype="step", color="red",label="DY")
plt.xlabel(r"$\min\{\Delta \eta(\mu\mu, j_1), \Delta \eta(\mu\mu, j_2)\}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
plt.hist(mmj_min_dEta_nominal_af, bins=50, density=True, weights=wgt_af, range=(0,8), histtype="step", color="blue", label="Signal")
plt.hist(mmj_min_dEta_nominal, bins=50, density=True, weights=wgt, range=(0,8), histtype="step", color="red",label="DY")
plt.xlabel(r"$\min\{\Delta \phi(\mu\mu, j_1), \Delta \phi(\mu\mu, j_2)\}$")
plt.ylabel("a.u.")
plt.legend()
plt.yscale("log") 
#plt.ylim(1e1, 1e5)
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
for c in df.columns:
    print(c)
# Out:
# event
# PV_npvs
# PV_npvsGood
# MET_pt
# MET_phi
# MET_sumEt
# mu1_pt
# mu1_ptErr
# mu2_pt
# mu2_ptErr
# mu1_pt_over_mass
# mu2_pt_over_mass
# mu1_eta
# mu2_eta
# mu1_phi
# mu2_phi
# mu1_charge
# mu2_charge
# mu1_iso
# mu2_iso
# nmuons
# dimuon_mass
# dimuon_pt
# dimuon_pt_log
# dimuon_eta
# dimuon_rapidity
# dimuon_phi
# dimuon_dEta
# dimuon_dPhi
# dimuon_dR
# acoplanarity
# dimuon_ebe_mass_res
# dimuon_ebe_mass_res_rel
# uncalibrated_dimuon_ebe_mass_res
# dimuon_cos_theta_cs
# dimuon_phi_cs
# dimuon_cos_theta_eta
# dimuon_phi_eta
# mu1_pt_raw
# mu2_pt_raw
# mu1_pt_fsr
# mu2_pt_fsr
# year
# run
# luminosityBlock
# fraction
# jet1_default_pt_nominal
# jet1_default_eta_nominal
# jet2_default_pt_nominal
# jet2_default_eta_nominal
# gjet1_pt
# gjet1_eta
# gjet1_phi
# gjet1_mass
# gjet2_pt
# gjet2_eta
# gjet2_phi
# gjet2_mass
# gjj_pt
# gjj_eta
# gjj_phi
# gjj_mass
# gjj_dEta
# gjj_dPhi
# gjj_dR
# jet1_pt_nominal
# jet1_eta_nominal
# jet1_rapidity_nominal
# jet1_phi_nominal
# ...

# %%
dfD.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 dfD.columns
#
# NameError: name 'dfD' is not defined

# %%
dfD.loc[:50,:].compute()

# %%
! ls /depot/cms/users/hu1027/hmm/copperheadV1clean/test_sep2025/stage1_output/2018/f1_0/

# %%
print(df.head())

# %%
# df.columns.tolist()
for col in df.columns:
    if "even" in col:
        print(col)

# %%
df["event"]

# %%
print(df.columns)

# %%
print(df["mu1_pt"][:10])

# %%
import matplotlib.pyplot as plt

# %%
# !ls /eos/purdue/store/user/rasharma/customNanoAOD/UL2018/GluGluHToMuMu_M125_TuneCP5_13TeV-powheg-pythia8

# %%
plt.hist(df["mu1_pt"], bins=50, range=(0,200), histtype="step", color="blue", label="Signal", label=r"$\mu_1 \, p_T$")
plt.hist(df["mu2_pt"], bins=50, range=(0,200), histtype="step", color="red",label="DY", label=r"$\mu_2 \, p_T$")

plt.xlabel(r"Muon $p_T$ [GeV]")
plt.ylabel("a.u.")plt.legend()
plt.title(r"Distribution of leading ($\mu_1$) and subleading ($\mu_2$) muon $p_T$")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()
